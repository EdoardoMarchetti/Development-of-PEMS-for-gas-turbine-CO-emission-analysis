# %%
import matplotlib.pyplot as plt

# %%
results = [1.377, 1.349, 1.288, 1.1699, 1.1697] 
label = ['(1)', '(2)', '(3)', '(4)', '(5)'] 
ticks = ['RFR', 'RFR - [CDP,TEY]', 'poly2+RFR', 'poly2+RFR+RS', 'poly2+RFR+HGS']
 
plt.plot(label, results, label, results, 'o', color='firebrick') 
ax = plt.gca() 
ax.set_ylim([0, 1.6]) 
ax.set_xticklabels(ticks, rotation = 45, ha = 'right' )
ax.set_ylabel('MSE, mg/m^3')
plt.grid(True, alpha=0.5) 
plt.savefig("figures/results.svg") 
plt.show()
# Out:
# /tmp/ipykernel_4952/3138663492.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ticks, rotation = 45, ha = 'right' )
